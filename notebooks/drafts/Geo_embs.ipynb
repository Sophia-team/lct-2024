# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"

import pandas as pd
import numpy as np
import torch
from functools import partial
import pytorch_lightning as pl
import warnings
import pickle
warnings.filterwarnings("ignore")

from torch.utils.data import DataLoader

from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.iterable_processing.iterable_seq_len_limit import ISeqLenLimit
from ptls.data_load.iterable_processing.to_torch_tensor import ToTorch
from ptls.data_load.iterable_processing.feature_filter import FeatureFilter
from ptls.nn import TrxEncoder, RnnSeqEncoder
from ptls.frames.coles import CoLESModule
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.frames.coles import ColesIterableDataset
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.frames import PtlsDataModule
from ptls.preprocessing import PandasDataPreprocessor
from ptls.data_load.utils import collate_feature_dict
from ptls.data_load.iterable_processing_dataset import IterableProcessingDataset

from tqdm.auto import tqdm
import lightgbm as ltb
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %% [markdown]
# # Part 1

# %%
geo_train = pd.read_parquet("geo_train.parquet")
geo_test = pd.read_parquet("geo_test.parquet")

# %%
preprocessor = PandasDataPreprocessor(
    col_id="client_id",
    col_event_time="event_time",
    event_time_transformation="dt_to_timestamp",
    cols_category=["geohash_4",
                   "geohash_5",
                   "geohash_6",],
    return_records=False,
)

# %%
preprocessor = preprocessor.fit(geo_train)
# Out:
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out
# IOStream.flush timed out

# %%
with open('geo_preprocessor.pkl', 'wb') as f:
    pickle.dump(preprocessor, f)

# %%
with open('geo_preprocessor.pkl', 'rb') as f:
    preprocessor = pickle.load(f)

# %%
processed_train = preprocessor.transform(geo_train)
processed_test = preprocessor.transform(geo_test)
# Out:
# IOStream.flush timed out
# IOStream.flush timed out

# %%
processed_train.to_pickle('geo_processed_train.pkl')
processed_test.to_pickle('geo_processed_test.pkl')

# %% [markdown]
# # Part 2

# %%
processed_train = pd.read_pickle('geo_processed_train.pkl')

# %%
processed_test = pd.read_pickle('geo_processed_test.pkl')

# %%
with open('geo_preprocessor.pkl', 'rb') as f:
    preprocessor = pickle.load(f)

# %%
train = MemoryMapDataset(
    data=processed_train.to_dict("records"),
    i_filters=[
        FeatureFilter(drop_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
        SeqLenFilter(min_seq_len=64),
        ISeqLenLimit(max_seq_len=4096),
        ToTorch()
    ]
)

test = MemoryMapDataset(
    data=processed_test.to_dict("records"),
    i_filters=[
        FeatureFilter(drop_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
        SeqLenFilter(min_seq_len=64),
        ISeqLenLimit(max_seq_len=4096),
        ToTorch()
    ]
)

# %%
train_ds = ColesIterableDataset(
    data=train,
    splitter=SampleSlices(
        split_count=5,
        cnt_min=32,
        cnt_max=180
    )
)

valid_ds = ColesIterableDataset(
    data=test,
    splitter=SampleSlices(
        split_count=5,
        cnt_min=32,
        cnt_max=180
    )
)

# %%
train_dl = PtlsDataModule(
    train_data=train_ds,
    train_num_workers=8,
    train_batch_size=256,
    valid_data=valid_ds,
    valid_num_workers=8,
    valid_batch_size=256
)

# %%
trx_encoder_params = dict(
    embeddings_noise=0.003,
    embeddings={
        'geohash_4': {'in': preprocessor.get_category_dictionary_sizes()["geohash_4"], 'out': 24},
        'geohash_5': {'in': preprocessor.get_category_dictionary_sizes()["geohash_5"], 'out': 24},
        'geohash_6': {'in': preprocessor.get_category_dictionary_sizes()["geohash_6"], 'out': 24},
      }
)

# %%
seq_encoder = RnnSeqEncoder(
    trx_encoder=TrxEncoder(**trx_encoder_params),
    hidden_size=64,
    type='gru',
)

# %%
model = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=0.001),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=3, gamma=0.9025)
)

# %%
trainer = pl.Trainer(
    max_epochs=30,
    limit_val_batches=5000,
    # gpus=[0],
    enable_progress_bar=True,
    gradient_clip_val=0.5,
    logger=pl.loggers.TensorBoardLogger(
        save_dir='./logdir',
        name='geo_result'
    ),
    callbacks=[
        pl.callbacks.LearningRateMonitor(logging_interval='step'),
        pl.callbacks.ModelCheckpoint(every_n_train_steps=5000, save_top_k=-1),
        pl.callbacks.EarlyStopping(monitor="valid/recall_top_k", mode="max", patience=5),
        pl.callbacks.EarlyStopping(monitor="loss", mode="min", patience=3),
    ]
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_dl)
# Out:
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# 2024-06-16 04:46:32.414118: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-16 04:46:35.192465: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name               | Type            | Params | Mode
# ---------------------------------------------------------------
# 0 | _loss              | ContrastiveLoss | 0      | train
# 1 | _seq_encoder       | RnnSeqEncoder   | 47.7 M | train
# 2 | _validation_metric | BatchRecallTopK | 0      | train
# 3 | _head              | Head            | 0      | train
# ---------------------------------------------------------------
# 47.7 M    Trainable params
# 0         Non-trainable params
# 47.7 M    Total params
# 190.655   Total estimated model params size (MB)
# Epoch 0: 100%|██████████| 2086/2086 [02:01<00:00, 17.12it/s, v_num=1, seq_len=104.0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/555 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/555 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/555 [00:00<00:24, 22.59it/s]
# Validation DataLoader 0:   0%|          | 2/555 [00:00<00:26, 20.78it/s]
# Validation DataLoader 0:   1%|          | 3/555 [00:00<00:26, 20.92it/s]
# Validation DataLoader 0:   1%|          | 4/555 [00:00<00:26, 20.64it/s]
# Validation DataLoader 0:   1%|          | 5/555 [00:00<00:26, 20.93it/s]
# Validation DataLoader 0:   1%|          | 6/555 [00:00<00:26, 20.56it/s]
# Validation DataLoader 0:   1%|▏         | 7/555 [00:00<00:26, 20.69it/s]
# Validation DataLoader 0:   1%|▏         | 8/555 [00:00<00:26, 20.82it/s]
# Validation DataLoader 0:   2%|▏         | 9/555 [00:00<00:26, 20.96it/s]
# Validation DataLoader 0:   2%|▏         | 10/555 [00:00<00:25, 21.03it/s]
# Validation DataLoader 0:   2%|▏         | 11/555 [00:00<00:25, 21.05it/s]
# Validation DataLoader 0:   2%|▏         | 12/555 [00:00<00:25, 21.14it/s]
# Validation DataLoader 0:   2%|▏         | 13/555 [00:00<00:25, 20.88it/s]
# Validation DataLoader 0:   3%|▎         | 14/555 [00:00<00:25, 20.86it/s]
# Validation DataLoader 0:   3%|▎         | 15/555 [00:00<00:25, 20.96it/s]
# Validation DataLoader 0:   3%|▎         | 16/555 [00:00<00:25, 20.94it/s]
# Validation DataLoader 0:   3%|▎         | 17/555 [00:00<00:25, 20.96it/s]
# Validation DataLoader 0:   3%|▎         | 18/555 [00:00<00:25, 20.97it/s]
# Validation DataLoader 0:   3%|▎         | 19/555 [00:00<00:25, 20.99it/s]
# Validation DataLoader 0:   4%|▎         | 20/555 [00:00<00:25, 21.00it/s]
# Validation DataLoader 0:   4%|▍         | 21/555 [00:00<00:25, 21.08it/s]
# Validation DataLoader 0:   4%|▍         | 22/555 [00:01<00:25, 21.11it/s]
# Validation DataLoader 0:   4%|▍         | 23/555 [00:01<00:25, 21.19it/s]
# Validation DataLoader 0:   4%|▍         | 24/555 [00:01<00:25, 21.23it/s]
# Validation DataLoader 0:   5%|▍         | 25/555 [00:01<00:24, 21.28it/s]
# Validation DataLoader 0:   5%|▍         | 26/555 [00:01<00:24, 21.33it/s]
# Validation DataLoader 0:   5%|▍         | 27/555 [00:01<00:24, 21.39it/s]
# Validation DataLoader 0:   5%|▌         | 28/555 [00:01<00:24, 21.45it/s]
# Validation DataLoader 0:   5%|▌         | 29/555 [00:01<00:24, 21.52it/s]
# Validation DataLoader 0:   5%|▌         | 30/555 [00:01<00:24, 21.59it/s]
# Validation DataLoader 0:   6%|▌         | 31/555 [00:01<00:24, 21.60it/s]
# Validation DataLoader 0:   6%|▌         | 32/555 [00:01<00:24, 21.62it/s]
# Validation DataLoader 0:   6%|▌         | 33/555 [00:01<00:24, 21.65it/s]
# Validation DataLoader 0:   6%|▌         | 34/555 [00:01<00:24, 21.67it/s]
# Validation DataLoader 0:   6%|▋         | 35/555 [00:01<00:23, 21.71it/s]
# Validation DataLoader 0:   6%|▋         | 36/555 [00:01<00:23, 21.75it/s]
# Validation DataLoader 0:   7%|▋         | 37/555 [00:01<00:23, 21.80it/s]
# Validation DataLoader 0:   7%|▋         | 38/555 [00:01<00:23, 21.84it/s]
# Validation DataLoader 0:   7%|▋         | 39/555 [00:01<00:23, 21.84it/s]
# Validation DataLoader 0:   7%|▋         | 40/555 [00:01<00:23, 21.86it/s]
# Validation DataLoader 0:   7%|▋         | 41/555 [00:01<00:23, 21.88it/s]
# Validation DataLoader 0:   8%|▊         | 42/555 [00:01<00:23, 21.89it/s]
# Validation DataLoader 0:   8%|▊         | 43/555 [00:01<00:23, 21.92it/s]
# Validation DataLoader 0:   8%|▊         | 44/555 [00:02<00:23, 21.94it/s]
# Validation DataLoader 0:   8%|▊         | 45/555 [00:02<00:23, 21.98it/s]
# Validation DataLoader 0:   8%|▊         | 46/555 [00:02<00:23, 22.01it/s]
# Validation DataLoader 0:   8%|▊         | 47/555 [00:02<00:23, 22.03it/s]
# Validation DataLoader 0:   9%|▊         | 48/555 [00:02<00:23, 22.04it/s]
# Validation DataLoader 0:   9%|▉         | 49/555 [00:02<00:22, 22.05it/s]
# Validation DataLoader 0:   9%|▉         | 50/555 [00:02<00:22, 22.06it/s]
# Validation DataLoader 0:   9%|▉         | 51/555 [00:02<00:22, 22.08it/s]
# Validation DataLoader 0:   9%|▉         | 52/555 [00:02<00:22, 22.10it/s]
# Validation DataLoader 0:  80%|████████  | 445/555 [00:19<00:04, 22.75it/s]
# Validation DataLoader 0:  80%|████████  | 446/555 [00:19<00:04, 22.75it/s]
# Validation DataLoader 0:  81%|████████  | 447/555 [00:19<00:04, 22.75it/s]
# Validation DataLoader 0:  81%|████████  | 448/555 [00:19<00:04, 22.75it/s]
# Validation DataLoader 0:  81%|████████  | 449/555 [00:19<00:04, 22.74it/s]
# Validation DataLoader 0:  81%|████████  | 450/555 [00:19<00:04, 22.74it/s]
# Validation DataLoader 0:  81%|████████▏ | 451/555 [00:19<00:04, 22.74it/s]
# Validation DataLoader 0:  81%|████████▏ | 452/555 [00:19<00:04, 22.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 453/555 [00:19<00:04, 22.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 454/555 [00:19<00:04, 22.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 455/555 [00:20<00:04, 22.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 456/555 [00:20<00:04, 22.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 457/555 [00:20<00:04, 22.74it/s]
# Validation DataLoader 0:  83%|████████▎ | 458/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  83%|████████▎ | 459/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  83%|████████▎ | 460/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  83%|████████▎ | 461/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  83%|████████▎ | 462/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  83%|████████▎ | 463/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  84%|████████▎ | 464/555 [00:20<00:04, 22.73it/s]
# Validation DataLoader 0:  84%|████████▍ | 465/555 [00:20<00:03, 22.73it/s]
# Validation DataLoader 0:  84%|████████▍ | 466/555 [00:20<00:03, 22.73it/s]
# Validation DataLoader 0:  84%|████████▍ | 467/555 [00:20<00:03, 22.72it/s]
# Validation DataLoader 0:  84%|████████▍ | 468/555 [00:20<00:03, 22.72it/s]
# Validation DataLoader 0:  85%|████████▍ | 469/555 [00:20<00:03, 22.72it/s]
# Validation DataLoader 0:  85%|████████▍ | 470/555 [00:20<00:03, 22.72it/s]
# Validation DataLoader 0:  85%|████████▍ | 471/555 [00:20<00:03, 22.72it/s]
# Validation DataLoader 0:  85%|████████▌ | 472/555 [00:20<00:03, 22.72it/s]
# Validation DataLoader 0:  85%|████████▌ | 473/555 [00:20<00:03, 22.71it/s]
# Validation DataLoader 0:  85%|████████▌ | 474/555 [00:20<00:03, 22.71it/s]
# Validation DataLoader 0:  86%|████████▌ | 475/555 [00:20<00:03, 22.71it/s]
# Validation DataLoader 0:  86%|████████▌ | 476/555 [00:20<00:03, 22.71it/s]
# Validation DataLoader 0:  86%|████████▌ | 477/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  86%|████████▌ | 478/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  86%|████████▋ | 479/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  86%|████████▋ | 480/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  87%|████████▋ | 481/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  87%|████████▋ | 482/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  87%|████████▋ | 483/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  87%|████████▋ | 484/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  87%|████████▋ | 485/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 486/555 [00:21<00:03, 22.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 487/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 488/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 489/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 490/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  88%|████████▊ | 491/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  89%|████████▊ | 492/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 493/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 494/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 495/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  89%|████████▉ | 496/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  90%|████████▉ | 497/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  90%|████████▉ | 498/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  90%|████████▉ | 499/555 [00:21<00:02, 22.71it/s]
# Validation DataLoader 0:  90%|█████████ | 500/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  90%|█████████ | 501/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  90%|█████████ | 502/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  91%|█████████ | 503/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  91%|█████████ | 504/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  91%|█████████ | 505/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  91%|█████████ | 506/555 [00:22<00:02, 22.71it/s]
# Validation DataLoader 0:  91%|█████████▏| 507/555 [00:22<00:02, 22.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 508/555 [00:22<00:02, 22.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 509/555 [00:22<00:02, 22.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 510/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 511/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 512/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  92%|█████████▏| 513/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  93%|█████████▎| 514/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  93%|█████████▎| 515/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  93%|█████████▎| 516/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  93%|█████████▎| 517/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  93%|█████████▎| 518/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  94%|█████████▎| 519/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  94%|█████████▎| 520/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  94%|█████████▍| 521/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  94%|█████████▍| 522/555 [00:22<00:01, 22.70it/s]
# Validation DataLoader 0:  94%|█████████▍| 523/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  94%|█████████▍| 524/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  95%|█████████▍| 525/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  95%|█████████▍| 526/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  95%|█████████▍| 527/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  95%|█████████▌| 528/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  95%|█████████▌| 529/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  95%|█████████▌| 530/555 [00:23<00:01, 22.70it/s]
# Validation DataLoader 0:  96%|█████████▌| 531/555 [00:23<00:01, 22.69it/s]
# Validation DataLoader 0:  96%|█████████▌| 532/555 [00:23<00:01, 22.69it/s]
# Validation DataLoader 0:  96%|█████████▌| 533/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  96%|█████████▌| 534/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  96%|█████████▋| 535/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  97%|█████████▋| 536/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  97%|█████████▋| 537/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  97%|█████████▋| 538/555 [00:23<00:00, 22.70it/s]
# Validation DataLoader 0:  97%|█████████▋| 539/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  97%|█████████▋| 540/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  97%|█████████▋| 541/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  98%|█████████▊| 542/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  98%|█████████▊| 543/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  98%|█████████▊| 544/555 [00:23<00:00, 22.69it/s]
# Validation DataLoader 0:  98%|█████████▊| 545/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  98%|█████████▊| 546/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  99%|█████████▊| 547/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  99%|█████████▊| 548/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  99%|█████████▉| 549/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  99%|█████████▉| 550/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  99%|█████████▉| 551/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0:  99%|█████████▉| 552/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0: 100%|█████████▉| 553/555 [00:24<00:00, 22.69it/s]
# Validation DataLoader 0: 100%|█████████▉| 554/555 [00:24<00:00, 22.70it/s]
# Validation DataLoader 0: 100%|██████████| 555/555 [00:24<00:00, 22.70it/s]
# Epoch 1: 100%|██████████| 2086/2086 [02:10<00:00, 16.04it/s, v_num=1, seq_len=102.0, valid/recall_top_k=0.948]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/555 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/555 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/555 [00:00<00:24, 22.98it/s]
# Validation DataLoader 0:   0%|          | 2/555 [00:00<00:28, 19.41it/s]
# Validation DataLoader 0:   1%|          | 3/555 [00:00<00:27, 20.23it/s]
# Validation DataLoader 0:   1%|          | 4/555 [00:00<00:26, 20.51it/s]
# Validation DataLoader 0:   1%|          | 5/555 [00:00<00:26, 20.79it/s]
# Validation DataLoader 0:   1%|          | 6/555 [00:00<00:26, 20.93it/s]
# Validation DataLoader 0:   1%|▏         | 7/555 [00:00<00:26, 21.01it/s]
# Validation DataLoader 0:   1%|▏         | 8/555 [00:00<00:26, 20.43it/s]
# Validation DataLoader 0:   2%|▏         | 9/555 [00:00<00:26, 20.47it/s]
# Validation DataLoader 0:   2%|▏         | 10/555 [00:00<00:26, 20.26it/s]
# Validation DataLoader 0:   2%|▏         | 11/555 [00:00<00:26, 20.42it/s]
# Validation DataLoader 0:   2%|▏         | 12/555 [00:00<00:26, 20.56it/s]
# Validation DataLoader 0:   2%|▏         | 13/555 [00:00<00:26, 20.60it/s]
# Validation DataLoader 0:   3%|▎         | 14/555 [00:00<00:26, 20.69it/s]
# Validation DataLoader 0:   3%|▎         | 15/555 [00:00<00:25, 20.78it/s]
# Validation DataLoader 0:   3%|▎         | 16/555 [00:00<00:25, 20.75it/s]
# Validation DataLoader 0:   3%|▎         | 17/555 [00:00<00:25, 20.74it/s]
# Validation DataLoader 0:   3%|▎         | 18/555 [00:00<00:25, 20.76it/s]
# Validation DataLoader 0:   3%|▎         | 19/555 [00:00<00:25, 20.79it/s]
# Validation DataLoader 0:   4%|▎         | 20/555 [00:00<00:25, 20.87it/s]
# Validation DataLoader 0:   4%|▍         | 21/555 [00:01<00:25, 20.89it/s]
# Validation DataLoader 0:   4%|▍         | 22/555 [00:01<00:25, 20.95it/s]
# Validation DataLoader 0:   4%|▍         | 23/555 [00:01<00:25, 20.96it/s]
# Validation DataLoader 0:   4%|▍         | 24/555 [00:01<00:25, 20.97it/s]
# Validation DataLoader 0:   5%|▍         | 25/555 [00:01<00:25, 21.01it/s]
# Validation DataLoader 0:   5%|▍         | 26/555 [00:01<00:25, 21.02it/s]
# Validation DataLoader 0:   5%|▍         | 27/555 [00:01<00:25, 21.02it/s]
# Validation DataLoader 0:   5%|▌         | 28/555 [00:01<00:25, 21.02it/s]
# Validation DataLoader 0:   5%|▌         | 29/555 [00:01<00:25, 21.04it/s]
# Validation DataLoader 0:   5%|▌         | 30/555 [00:01<00:24, 21.04it/s]
# Validation DataLoader 0:   6%|▌         | 31/555 [00:01<00:24, 21.11it/s]
# Validation DataLoader 0:   6%|▌         | 32/555 [00:01<00:24, 21.15it/s]
# Validation DataLoader 0:   6%|▌         | 33/555 [00:01<00:24, 21.17it/s]
# Validation DataLoader 0:   6%|▌         | 34/555 [00:01<00:24, 21.22it/s]
# Validation DataLoader 0:   6%|▋         | 35/555 [00:01<00:24, 21.26it/s]
# Validation DataLoader 0:   6%|▋         | 36/555 [00:01<00:24, 21.29it/s]
# Validation DataLoader 0:   7%|▋         | 37/555 [00:01<00:24, 21.31it/s]
# Validation DataLoader 0:   7%|▋         | 38/555 [00:01<00:24, 21.33it/s]
# Validation DataLoader 0:   7%|▋         | 39/555 [00:01<00:24, 21.37it/s]
# Validation DataLoader 0:   7%|▋         | 40/555 [00:01<00:24, 21.40it/s]
# Validation DataLoader 0:   7%|▋         | 41/555 [00:01<00:24, 21.41it/s]
# Validation DataLoader 0:   8%|▊         | 42/555 [00:01<00:23, 21.44it/s]
# Validation DataLoader 0:   8%|▊         | 43/555 [00:02<00:23, 21.46it/s]
# Validation DataLoader 0:   8%|▊         | 44/555 [00:02<00:23, 21.48it/s]
# Validation DataLoader 0:   8%|▊         | 45/555 [00:02<00:23, 21.49it/s]
# Validation DataLoader 0:   8%|▊         | 46/555 [00:02<00:23, 21.51it/s]
# Validation DataLoader 0:   8%|▊         | 47/555 [00:02<00:23, 21.53it/s]
# Validation DataLoader 0:   9%|▊         | 48/555 [00:02<00:23, 21.55it/s]
# Validation DataLoader 0:   9%|▉         | 49/555 [00:02<00:23, 21.56it/s]
# Validation DataLoader 0:   9%|▉         | 50/555 [00:02<00:23, 21.58it/s]
# Validation DataLoader 0:   9%|▉         | 51/555 [00:02<00:23, 21.60it/s]
# Validation DataLoader 0:   9%|▉         | 52/555 [00:02<00:23, 21.60it/s]
# Validation DataLoader 0:  10%|▉         | 53/555 [00:02<00:23, 21.61it/s]
# Validation DataLoader 0:  10%|▉         | 54/555 [00:02<00:23, 21.61it/s]
555 [00:21<00:03, 22.50it/s]
# Validation DataLoader 0:  87%|████████▋ | 485/555 [00:21<00:03, 22.50it/s]
# Validation DataLoader 0:  88%|████████▊ | 486/555 [00:21<00:03, 22.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 487/555 [00:21<00:03, 22.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 488/555 [00:21<00:02, 22.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 489/555 [00:21<00:02, 22.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 490/555 [00:21<00:02, 22.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 491/555 [00:21<00:02, 22.50it/s]
# Validation DataLoader 0:  89%|████████▊ | 492/555 [00:21<00:02, 22.51it/s]
# Validation DataLoader 0:  89%|████████▉ | 493/555 [00:21<00:02, 22.51it/s]
# Validation DataLoader 0:  89%|████████▉ | 494/555 [00:21<00:02, 22.50it/s]
# Validation DataLoader 0:  89%|████████▉ | 495/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  89%|████████▉ | 496/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  90%|████████▉ | 497/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  90%|████████▉ | 498/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  90%|████████▉ | 499/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  90%|█████████ | 500/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  90%|█████████ | 501/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  90%|█████████ | 502/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  91%|█████████ | 503/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  91%|█████████ | 504/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  91%|█████████ | 505/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  91%|█████████ | 506/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  91%|█████████▏| 507/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  92%|█████████▏| 508/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  92%|█████████▏| 509/555 [00:22<00:02, 22.50it/s]
# Validation DataLoader 0:  92%|█████████▏| 510/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  92%|█████████▏| 511/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  92%|█████████▏| 512/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  92%|█████████▏| 513/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  93%|█████████▎| 514/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  93%|█████████▎| 515/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  93%|█████████▎| 516/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  93%|█████████▎| 517/555 [00:22<00:01, 22.51it/s]
# Validation DataLoader 0:  93%|█████████▎| 518/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  94%|█████████▎| 519/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  94%|█████████▎| 520/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  94%|█████████▍| 521/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  94%|█████████▍| 522/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  94%|█████████▍| 523/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  94%|█████████▍| 524/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  95%|█████████▍| 525/555 [00:23<00:01, 22.51it/s]
# Validation DataLoader 0:  95%|█████████▍| 526/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  95%|█████████▍| 527/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  95%|█████████▌| 528/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  95%|█████████▌| 529/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  95%|█████████▌| 530/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  96%|█████████▌| 531/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  96%|█████████▌| 532/555 [00:23<00:01, 22.52it/s]
# Validation DataLoader 0:  96%|█████████▌| 533/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  96%|█████████▌| 534/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  96%|█████████▋| 535/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  97%|█████████▋| 536/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  97%|█████████▋| 537/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  97%|█████████▋| 538/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  97%|█████████▋| 539/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  97%|█████████▋| 540/555 [00:23<00:00, 22.52it/s]
# Validation DataLoader 0:  97%|█████████▋| 541/555 [00:24<00:00, 22.52it/s]
# Validation DataLoader 0:  98%|█████████▊| 542/555 [00:24<00:00, 22.52it/s]
# Validation DataLoader 0:  98%|█████████▊| 543/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  98%|█████████▊| 544/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  98%|█████████▊| 545/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  98%|█████████▊| 546/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  99%|█████████▊| 547/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  99%|█████████▊| 548/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  99%|█████████▉| 549/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  99%|█████████▉| 550/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  99%|█████████▉| 551/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0:  99%|█████████▉| 552/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0: 100%|█████████▉| 553/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0: 100%|█████████▉| 554/555 [00:24<00:00, 22.53it/s]
# Validation DataLoader 0: 100%|██████████| 555/555 [00:24<00:00, 22.53it/s]
# Epoch 7: 100%|██████████| 2086/2086 [02:33<00:00, 13.57it/s, v_num=1, seq_len=101.0, valid/recall_top_k=0.948]

# %%
torch.save(model.state_dict(), './geo_emb64_model.pt')

# %% [markdown]
# # Part 3

# %%
processed_train = pd.read_pickle('geo_processed_train.pkl')

# %%
processed_test = pd.read_pickle('geo_processed_test.pkl')

# %%
# processed_target = pd.read_pickle('processed_target.pkl')
target_train = pd.read_parquet("train_target.parquet")
target_test = pd.read_parquet("test_target_b.parquet")

# %%
with open('geo_preprocessor.pkl', 'rb') as f:
    preprocessor = pickle.load(f)

# %%
import gc
gc.collect()

# %%
trx_encoder_params = dict(
    embeddings_noise=0.003,
    embeddings={
        'geohash_4': {'in': preprocessor.get_category_dictionary_sizes()["geohash_4"], 'out': 24},
        'geohash_5': {'in': preprocessor.get_category_dictionary_sizes()["geohash_5"], 'out': 24},
        'geohash_6': {'in': preprocessor.get_category_dictionary_sizes()["geohash_6"], 'out': 24},
      }
)
seq_encoder = RnnSeqEncoder(
    trx_encoder=TrxEncoder(**trx_encoder_params),
    hidden_size=64,
    type='gru',
)


model = model = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=0.001),
    lr_scheduler_partial=partial(torch.optim.lr_scheduler.StepLR, step_size=3, gamma=0.9025)
)
model.load_state_dict(torch.load('./geo_emb64_model.pt'))
model.eval()

# %%
device  = torch.device("cuda")
model = model.to(device)

# %%
from pandas.tseries.offsets import MonthBegin


class GetSplit(IterableProcessingDataset):
    def __init__(
        self,
        months,
        col_id='client_id',
        col_time='event_time'
    ):
        super().__init__()
        self.months = months
        self._col_id = col_id
        self._col_time = col_time

    def __iter__(self):
        for rec in self._src:
            for i, month in enumerate(self.months):
                features = rec[0] if type(rec) is tuple else rec
                features = features.copy()

                month_event_time = int((pd.to_datetime(month, yearfirst=True, dayfirst=False) - MonthBegin(1)).to_datetime64()) / 1e9
                mask = features[self._col_time] < month_event_time

                for key, tensor in features.items():
                    if key.startswith('target'):
                        features[key] = tensor[i].tolist()
                    elif key != self._col_id:
                        features[key] = tensor[mask]

                features[self._col_id] += '__' + str(month)

                yield features
                

from datetime import datetime


def collate_feature_dict_with_target(batch, col_id='client_id', targets=False):
    batch_ids = []
    target_cols = []
    for sample in batch:
        batch_ids.append(sample[col_id])
        del sample[col_id]

        if targets:
            target_cols.append([sample[f'target_{i}'] for i in range(1, 5)])
            del sample['target_1']
            del sample['target_2']
            del sample['target_3']
            del sample['target_4']

    padded_batch = collate_feature_dict(batch)
    if targets:
        return padded_batch, batch_ids, target_cols
    return padded_batch, batch_ids

def to_pandas(x):
    with torch.no_grad():
        expand_cols = []
        scalar_features = {}
        for k, v in x.items():
            if type(v) is torch.Tensor:
                v = v.cpu().detach().numpy()
            if type(v) is list or len(v.shape) == 1:
                scalar_features[k] = v
            elif len(v.shape) == 2:
                expand_cols.append(k)
            else:
                scalar_features[k] = None
        dataframes = [pd.DataFrame(scalar_features)]
        for col in expand_cols:
            v = x[col].cpu().detach().numpy()
            dataframes.append(pd.DataFrame(v, columns=[f'{col}_{i:04d}' for i in range(v.shape[1])]))
        return pd.concat(dataframes, axis=1)

# %%
from tqdm import tqdm

def make_prediction(model, inference_dl):
    dfs = []
    for x in tqdm(inference_dl):
        x_len = len(x)
        if x_len == 3:
            x, batch_ids, target_cols = x
        else:
            x, batch_ids = x
        out = model(x.to(device))
        if x_len == 3:
            target_cols = torch.tensor(target_cols)
            x_out = {
                'client_id': batch_ids,
                'target_1': target_cols[:, 0],
                'target_2': target_cols[:, 1],
                'target_3': target_cols[:, 2],
                'target_4': target_cols[:, 3],
                'emb': out
            }
        else:
            x_out = {
                'client_id': batch_ids,
                'emb': out
            }
        torch.cuda.empty_cache()
        dfs.append(to_pandas(x_out))
    return pd.concat(dfs, axis='rows')


def get_train_dataset(processed_data, model, months):
    train = MemoryMapDataset(
        data=processed_data.to_dict("records"),
        i_filters=[
            ISeqLenLimit(max_seq_len=4096),
            FeatureFilter(keep_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
            GetSplit(months=months),
            ToTorch(),
        ]
    )

    inference_train_dl = DataLoader(
            dataset=train,
            collate_fn=collate_feature_dict_with_target,
            shuffle=False,
            num_workers=0,
            batch_size=256,
        )
    
    train_emb_df = make_prediction(model, inference_train_dl)
    train_emb_df[['client_id', 'month']] = train_emb_df['client_id'].str.split('__', n=1, expand=True)
    return train_emb_df


def get_val_dataset(processed_data, model, months):
    val = MemoryMapDataset(
        data=processed_data.to_dict("records"),
        i_filters=[
            ISeqLenLimit(max_seq_len=4096),
            FeatureFilter(keep_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
            GetSplit(months=months),
            ToTorch(),
        ]
    )
    inference_val_dl = DataLoader(
            dataset=val,
            collate_fn=collate_feature_dict_with_target,
            shuffle=False,
            num_workers=0,
            batch_size=256,
        )
    
    val_emb_df = make_prediction(model, inference_val_dl)
    val_emb_df[['client_id', 'month']] = val_emb_df['client_id'].str.split('__', n=1, expand=True)
    return val_emb_df


def get_test_dataset(processed_data, model):
    test = MemoryMapDataset(
        data=processed_data.to_dict("records"),
        i_filters=[
            ISeqLenLimit(max_seq_len=4096),
            FeatureFilter(keep_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
            ToTorch(),
        ]
    )

    inference_test_dl = DataLoader(
            dataset=test,
            collate_fn=collate_feature_dict_with_target,
            shuffle=False,
            num_workers=0,
            batch_size=256,
        )
    
    test_emb_df = make_prediction(model, inference_test_dl)
    return test_emb_df

# %%
del part3, train_emb_df_part3

# %%
import gc
gc.collect()
# Out:
# 115

# %%
part4 = processed_train[450_000:]

# %%
train_emb_df_part4 = get_train_dataset(part4, model, sorted(target_train.mon.sort_values().unique()))
# Out:
# 100%|██████████| 8077/8077 [17:11<00:00,  7.83it/s]

# %%
train_emb_df_part4
# Out:
#                                              client_id  ...       month
# 0    b91d8218da3a9fe60e663ad7093e52eba853a6112a2f97...  ...  2022-02-28
# 1    b91d8218da3a9fe60e663ad7093e52eba853a6112a2f97...  ...  2022-03-31
# 2    b91d8218da3a9fe60e663ad7093e52eba853a6112a2f97...  ...  2022-04-30
# 3    b91d8218da3a9fe60e663ad7093e52eba853a6112a2f97...  ...  2022-05-31
# 4    b91d8218da3a9fe60e663ad7093e52eba853a6112a2f97...  ...  2022-06-30
# ..                                                 ...  ...         ...
# 187  fffff598cd1a947b8ce0b86d56fd356729ec7bacb7053a...  ...  2022-09-30
# 188  fffff598cd1a947b8ce0b86d56fd356729ec7bacb7053a...  ...  2022-10-31
# 189  fffff598cd1a947b8ce0b86d56fd356729ec7bacb7053a...  ...  2022-11-30
# 190  fffff598cd1a947b8ce0b86d56fd356729ec7bacb7053a...  ...  2022-12-31
# 191  fffff598cd1a947b8ce0b86d56fd356729ec7bacb7053a...  ...  2023-01-31
#
# [2067648 rows x 66 columns]

# %%
train_emb_df_part4.to_csv('train4_geo_emb_v2.csv', index=False)

# %%
1
# Out:
# 1

# %%
train_emb_df_part3.to_csv('train3_geo_emb_v2.csv', index=False)

# %%
train_emb_df_part2.to_csv('train2_geo_emb_v2.csv', index=False)

# %%
train_emb_df_part1.to_csv('train1_geo_emb_v2.csv', index=False)

# %%
val_emb_df = get_val_dataset(processed_test, model, sorted(target_test.mon.sort_values().unique()))
# Out:
# 100%|██████████| 7165/7165 [15:26<00:00,  7.74it/s]

# %%
val_emb_df.to_csv('val_geo_emb_v2.csv', index=False)

# %%
del val_emb_df

# %%
test_emb_df = get_test_dataset(processed_test, model)
# Out:
# 100%|██████████| 652/652 [23:09<00:00,  2.13s/it]

# %%
test_emb_df.to_csv('test_geo_emb_v2.csv', index=False)

# %%
del test_emb_df

# %%
del processed_test
