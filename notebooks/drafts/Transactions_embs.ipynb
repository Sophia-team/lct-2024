# %%
import os

os.environ["OMP_NUM_THREADS"] = "16"

import pickle
import warnings
from functools import partial

import numpy as np 
import pandas as pd
import pytorch_lightning as pl
import torch

warnings.filterwarnings("ignore")

import lightgbm as ltb
from ptls.data_load.datasets import MemoryMapDataset
from ptls.data_load.iterable_processing import SeqLenFilter
from ptls.data_load.iterable_processing.feature_filter import FeatureFilter
from ptls.data_load.iterable_processing.iterable_seq_len_limit import ISeqLenLimit
from ptls.data_load.iterable_processing.to_torch_tensor import ToTorch
from ptls.data_load.iterable_processing_dataset import IterableProcessingDataset
from ptls.data_load.utils import collate_feature_dict
from ptls.frames import PtlsDataModule
from ptls.frames.coles import ColesIterableDataset, CoLESModule
from ptls.frames.coles.split_strategy import SampleSlices
from ptls.nn import RnnSeqEncoder, TrxEncoder
from ptls.preprocessing import PandasDataPreprocessor
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

# %% [markdown]
# # Part 1

# %%
transactions_train = pd.read_parquet("trx_train.parquet")
transactions_test = pd.read_parquet("trx_test.parquet")

# %%
with open("transactions_preprocessor.pkl", "rb") as f:
    preprocessor = pickle.load(f)

# %%
processed_train = preprocessor.transform(transactions_train)
processed_test = preprocessor.transform(transactions_test)
# Out:
# IOStream.flush timed out

# %%
processed_train.to_pickle("processed_train.pkl")
processed_test.to_pickle("processed_test.pkl")
# Out:
# IOStream.flush timed out

# %% [markdown]
# # Part 2

# %%
processed_train = pd.read_pickle("processed_train.pkl")

# %%
processed_test = pd.read_pickle("processed_test.pkl")

# %%
with open("transactions_preprocessor.pkl", "rb") as f:
    preprocessor = pickle.load(f)

# %%
train = MemoryMapDataset(
    data=processed_train.sample(500_000).to_dict("records"),
    i_filters=[
        FeatureFilter(
            drop_feature_names=[
                "client_id",
                "target_1",
                "target_2",
                "target_3",
                "target_4",
            ]
        ),
        SeqLenFilter(min_seq_len=128),
        ISeqLenLimit(max_seq_len=2896),
        ToTorch(),
    ],
)

test = MemoryMapDataset(
    data=processed_test.to_dict("records"),
    i_filters=[
        FeatureFilter(
            drop_feature_names=[
                "client_id",
                "target_1",
                "target_2",
                "target_3",
                "target_4",
            ]
        ),
        SeqLenFilter(min_seq_len=128),
        ISeqLenLimit(max_seq_len=2896),
        ToTorch(),
    ],
)

# %%
train_ds = ColesIterableDataset(
    data=train, splitter=SampleSlices(split_count=5, cnt_min=32, cnt_max=160)
)

valid_ds = ColesIterableDataset(
    data=test, splitter=SampleSlices(split_count=5, cnt_min=32, cnt_max=160)
)

# %%
train_dl = PtlsDataModule(
    train_data=train_ds,
    train_num_workers=8,
    train_batch_size=256,
    valid_data=valid_ds,
    valid_num_workers=8,
    valid_batch_size=256,
)

# %%
import pickle

with open('train_dl.pkl', 'wb') as f:
    pickle.dump(train_dl, f)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import pickle

with open('train_dl.pkl', 'rb') as f:
    train_dl = pickle.load(f)

# %%
del train_dl

# %%
import gc
gc.collect()
# Out:
# 213

# %%
trx_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount": "log"},
    embeddings={
        "event_type": {
            "in": preprocessor.get_category_dictionary_sizes()["event_type"],
            "out": 8,
        },
        "event_subtype": {
            "in": preprocessor.get_category_dictionary_sizes()["event_subtype"],
            "out": 8,
        },
        "src_type11": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type11"],
            "out": 16,
        },
        "src_type12": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type12"],
            "out": 16,
        },
        "dst_type11": {
            "in": preprocessor.get_category_dictionary_sizes()["dst_type11"],
            "out": 16,
        },
        "dst_type12": {
            "in": preprocessor.get_category_dictionary_sizes()["dst_type12"],
            "out": 16,
        },
        "src_type22": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type22"],
            "out": 16
        },
        "src_type31": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type31"],
            "out": 16,
        },
        "src_type32": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type32"],
            "out": 16,
        },
    },
)

# %%
seq_encoder = RnnSeqEncoder(
    trx_encoder=TrxEncoder(**trx_encoder_params),
    hidden_size=64,
    type="gru",
)

# %%
model = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=0.001),
    lr_scheduler_partial=partial(
        torch.optim.lr_scheduler.StepLR, step_size=3, gamma=0.9025
    ),
)

# %%
trainer = pl.Trainer(
    max_epochs=30,
    limit_val_batches=5000,
    enable_progress_bar=True,
    gradient_clip_val=0.5,
    logger=pl.loggers.TensorBoardLogger(save_dir="./logdir", name="transaction_result"),
    callbacks=[
        pl.callbacks.LearningRateMonitor(logging_interval="step"),
        pl.callbacks.ModelCheckpoint(every_n_train_steps=5000, save_top_k=-1),
        pl.callbacks.EarlyStopping(monitor="valid/recall_top_k", mode="max", patience=5),
        pl.callbacks.EarlyStopping(monitor="loss", mode="min", patience=3),
    ],
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
torch.cuda.is_available()
# Out:
# True

# %%
trainer.fit(model, train_dl)
# Out:
# 2024-06-16 09:25:08.594150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-16 09:25:12.222820: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name               | Type            | Params | Mode
# ---------------------------------------------------------------
# 0 | _loss              | ContrastiveLoss | 0      | train
# 1 | _seq_encoder       | RnnSeqEncoder   | 92.5 K | train
# 2 | _validation_metric | BatchRecallTopK | 0      | train
# 3 | _head              | Head            | 0      | train
# ---------------------------------------------------------------
# 92.5 K    Trainable params
# 0         Non-trainable params
# 92.5 K    Total params
# 0.370     Total estimated model params size (MB)
# Epoch 0: 100%|██████████| 835/835 [02:14<00:00,  6.21it/s, v_num=7, seq_len=94.60]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/369 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/369 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/369 [00:00<00:53,  6.82it/s]
# Validation DataLoader 0:   1%|          | 2/369 [00:00<00:47,  7.76it/s]
# Validation DataLoader 0:   1%|          | 3/369 [00:00<00:55,  6.58it/s]
# Validation DataLoader 0:   1%|          | 4/369 [00:00<00:55,  6.60it/s]
# Validation DataLoader 0:   1%|▏         | 5/369 [00:00<00:56,  6.42it/s]
# Validation DataLoader 0:   2%|▏         | 6/369 [00:00<00:58,  6.22it/s]
# Validation DataLoader 0:   2%|▏         | 7/369 [00:01<00:55,  6.54it/s]
# Validation DataLoader 0:   2%|▏         | 8/369 [00:01<00:59,  6.11it/s]
# Validation DataLoader 0:   2%|▏         | 9/369 [00:01<01:01,  5.84it/s]
# Validation DataLoader 0:   3%|▎         | 10/369 [00:01<01:02,  5.73it/s]
# Validation DataLoader 0:   3%|▎         | 11/369 [00:01<01:01,  5.82it/s]
# Validation DataLoader 0:   3%|▎         | 12/369 [00:02<01:03,  5.61it/s]
# Validation DataLoader 0:   4%|▎         | 13/369 [00:02<01:01,  5.79it/s]
# Validation DataLoader 0:   4%|▍         | 14/369 [00:02<00:59,  5.94it/s]
# Validation DataLoader 0:   4%|▍         | 15/369 [00:02<00:58,  6.10it/s]
# Validation DataLoader 0:   4%|▍         | 16/369 [00:02<00:56,  6.25it/s]
# Validation DataLoader 0:   5%|▍         | 17/369 [00:02<00:55,  6.37it/s]
# Validation DataLoader 0:   5%|▍         | 18/369 [00:02<00:55,  6.37it/s]
# Validation DataLoader 0:   5%|▌         | 19/369 [00:02<00:54,  6.41it/s]
# Validation DataLoader 0:   5%|▌         | 20/369 [00:03<00:54,  6.41it/s]
# Validation DataLoader 0:   6%|▌         | 21/369 [00:03<00:53,  6.51it/s]
# Validation DataLoader 0:   6%|▌         | 22/369 [00:03<00:54,  6.38it/s]
# Validation DataLoader 0:   6%|▌         | 23/369 [00:03<00:53,  6.48it/s]
# Validation DataLoader 0:   7%|▋         | 24/369 [00:03<00:52,  6.59it/s]
# Validation DataLoader 0:   7%|▋         | 25/369 [00:03<00:52,  6.57it/s]
# Validation DataLoader 0:   7%|▋         | 26/369 [00:03<00:52,  6.58it/s]
# Validation DataLoader 0:   7%|▋         | 27/369 [00:04<00:51,  6.65it/s]
# Validation DataLoader 0:   8%|▊         | 28/369 [00:04<00:51,  6.64it/s]
# Validation DataLoader 0:   8%|▊         | 29/369 [00:04<00:50,  6.71it/s]
# Validation DataLoader 0:   8%|▊         | 30/369 [00:04<00:50,  6.76it/s]
# Validation DataLoader 0:   8%|▊         | 31/369 [00:04<00:49,  6.83it/s]
# Validation DataLoader 0:   9%|▊         | 32/369 [00:04<00:48,  6.88it/s]
# Validation DataLoader 0:   9%|▉         | 33/369 [00:04<00:48,  6.88it/s]
# Validation DataLoader 0:   9%|▉         | 34/369 [00:04<00:48,  6.89it/s]
# Validation DataLoader 0:   9%|▉         | 35/369 [00:05<00:49,  6.81it/s]
# Validation DataLoader 0:  10%|▉         | 36/369 [00:05<00:50,  6.65it/s]
# Validation DataLoader 0:  10%|█         | 37/369 [00:05<00:49,  6.65it/s]
# Validation DataLoader 0:  10%|█         | 38/369 [00:05<00:49,  6.67it/s]
# Validation DataLoader 0:  11%|█         | 39/369 [00:05<00:49,  6.73it/s]
# Validation DataLoader 0:  11%|█         | 40/369 [00:05<00:49,  6.71it/s]
# Validation DataLoader 0:  11%|█         | 41/369 [00:06<00:49,  6.69it/s]
# Validation DataLoader 0:  11%|█▏        | 42/369 [00:06<00:48,  6.71it/s]
# Validation DataLoader 0:  12%|█▏        | 43/369 [00:06<00:48,  6.73it/s]
# Validation DataLoader 0:  12%|█▏        | 44/369 [00:06<00:49,  6.62it/s]
# Validation DataLoader 0:  12%|█▏        | 45/369 [00:06<00:49,  6.60it/s]
# Validation DataLoader 0:  12%|█▏        | 46/369 [00:06<00:49,  6.59it/s]
# Validation DataLoader 0:  13%|█▎        | 47/369 [00:07<00:48,  6.63it/s]
# Validation DataLoader 0:  13%|█▎        | 48/369 [00:07<00:48,  6.67it/s]
# Validation DataLoader 0:  13%|█▎        | 49/369 [00:07<00:48,  6.65it/s]
# Validation DataLoader 0:  14%|█▎        | 50/369 [00:07<00:48,  6.64it/s]
# Validation DataLoader 0:  80%|███████▉  | 294/369 [00:40<00:10,  7.35it/s]
# Validation DataLoader 0:  80%|███████▉  | 295/369 [00:40<00:10,  7.35it/s]
# Validation DataLoader 0:  80%|████████  | 296/369 [00:40<00:09,  7.35it/s]
# Validation DataLoader 0:  80%|████████  | 297/369 [00:40<00:09,  7.35it/s]
# Validation DataLoader 0:  81%|████████  | 298/369 [00:40<00:09,  7.35it/s]
# Validation DataLoader 0:  81%|████████  | 299/369 [00:40<00:09,  7.36it/s]
# Validation DataLoader 0:  81%|████████▏ | 300/369 [00:40<00:09,  7.36it/s]
# Validation DataLoader 0:  82%|████████▏ | 301/369 [00:40<00:09,  7.36it/s]
# Validation DataLoader 0:  82%|████████▏ | 302/369 [00:41<00:09,  7.36it/s]
# Validation DataLoader 0:  82%|████████▏ | 303/369 [00:41<00:08,  7.37it/s]
# Validation DataLoader 0:  82%|████████▏ | 304/369 [00:41<00:08,  7.36it/s]
# Validation DataLoader 0:  83%|████████▎ | 305/369 [00:41<00:08,  7.35it/s]
# Validation DataLoader 0:  83%|████████▎ | 306/369 [00:41<00:08,  7.35it/s]
# Validation DataLoader 0:  83%|████████▎ | 307/369 [00:41<00:08,  7.35it/s]
# Validation DataLoader 0:  83%|████████▎ | 308/369 [00:41<00:08,  7.35it/s]
# Validation DataLoader 0:  84%|████████▎ | 309/369 [00:42<00:08,  7.35it/s]
# Validation DataLoader 0:  84%|████████▍ | 310/369 [00:42<00:08,  7.35it/s]
# Validation DataLoader 0:  84%|████████▍ | 311/369 [00:42<00:07,  7.36it/s]
# Validation DataLoader 0:  85%|████████▍ | 312/369 [00:42<00:07,  7.36it/s]
# Validation DataLoader 0:  85%|████████▍ | 313/369 [00:42<00:07,  7.35it/s]
# Validation DataLoader 0:  85%|████████▌ | 314/369 [00:42<00:07,  7.35it/s]
# Validation DataLoader 0:  85%|████████▌ | 315/369 [00:42<00:07,  7.34it/s]
# Validation DataLoader 0:  86%|████████▌ | 316/369 [00:43<00:07,  7.34it/s]
# Validation DataLoader 0:  86%|████████▌ | 317/369 [00:43<00:07,  7.35it/s]
# Validation DataLoader 0:  86%|████████▌ | 318/369 [00:43<00:06,  7.35it/s]
# Validation DataLoader 0:  86%|████████▋ | 319/369 [00:43<00:06,  7.35it/s]
# Validation DataLoader 0:  87%|████████▋ | 320/369 [00:43<00:06,  7.35it/s]
# Validation DataLoader 0:  87%|████████▋ | 321/369 [00:43<00:06,  7.35it/s]
# Validation DataLoader 0:  87%|████████▋ | 322/369 [00:43<00:06,  7.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 323/369 [00:43<00:06,  7.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 324/369 [00:44<00:06,  7.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 325/369 [00:44<00:05,  7.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 326/369 [00:44<00:05,  7.36it/s]
# Validation DataLoader 0:  89%|████████▊ | 327/369 [00:44<00:05,  7.37it/s]
# Validation DataLoader 0:  89%|████████▉ | 328/369 [00:44<00:05,  7.36it/s]
# Validation DataLoader 0:  89%|████████▉ | 329/369 [00:44<00:05,  7.36it/s]
# Validation DataLoader 0:  89%|████████▉ | 330/369 [00:44<00:05,  7.36it/s]
# Validation DataLoader 0:  90%|████████▉ | 331/369 [00:44<00:05,  7.36it/s]
# Validation DataLoader 0:  90%|████████▉ | 332/369 [00:45<00:05,  7.36it/s]
# Validation DataLoader 0:  90%|█████████ | 333/369 [00:45<00:04,  7.37it/s]
# Validation DataLoader 0:  91%|█████████ | 334/369 [00:45<00:04,  7.37it/s]
# Validation DataLoader 0:  91%|█████████ | 335/369 [00:45<00:04,  7.37it/s]
# Validation DataLoader 0:  91%|█████████ | 336/369 [00:45<00:04,  7.37it/s]
# Validation DataLoader 0:  91%|█████████▏| 337/369 [00:45<00:04,  7.37it/s]
# Validation DataLoader 0:  92%|█████████▏| 338/369 [00:45<00:04,  7.38it/s]
# Validation DataLoader 0:  92%|█████████▏| 339/369 [00:45<00:04,  7.38it/s]
# Validation DataLoader 0:  92%|█████████▏| 340/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  92%|█████████▏| 341/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  93%|█████████▎| 342/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  93%|█████████▎| 343/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  93%|█████████▎| 344/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  93%|█████████▎| 345/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  94%|█████████▍| 346/369 [00:46<00:03,  7.38it/s]
# Validation DataLoader 0:  94%|█████████▍| 347/369 [00:47<00:02,  7.37it/s]
# Validation DataLoader 0:  94%|█████████▍| 348/369 [00:47<00:02,  7.38it/s]
# Validation DataLoader 0:  95%|█████████▍| 349/369 [00:47<00:02,  7.38it/s]
# Validation DataLoader 0:  95%|█████████▍| 350/369 [00:47<00:02,  7.38it/s]
# Validation DataLoader 0:  95%|█████████▌| 351/369 [00:47<00:02,  7.38it/s]
# Validation DataLoader 0:  95%|█████████▌| 352/369 [00:47<00:02,  7.38it/s]
# Validation DataLoader 0:  96%|█████████▌| 353/369 [00:47<00:02,  7.39it/s]
# Validation DataLoader 0:  96%|█████████▌| 354/369 [00:47<00:02,  7.39it/s]
# Validation DataLoader 0:  96%|█████████▌| 355/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  96%|█████████▋| 356/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  97%|█████████▋| 357/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  97%|█████████▋| 358/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  97%|█████████▋| 359/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  98%|█████████▊| 360/369 [00:48<00:01,  7.38it/s]
# Validation DataLoader 0:  98%|█████████▊| 361/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  98%|█████████▊| 362/369 [00:48<00:00,  7.39it/s]
# Validation DataLoader 0:  98%|█████████▊| 363/369 [00:49<00:00,  7.39it/s]
# Validation DataLoader 0:  99%|█████████▊| 364/369 [00:49<00:00,  7.40it/s]
# Validation DataLoader 0:  99%|█████████▉| 365/369 [00:49<00:00,  7.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 366/369 [00:49<00:00,  7.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 367/369 [00:49<00:00,  7.40it/s]
# Validation DataLoader 0: 100%|█████████▉| 368/369 [00:49<00:00,  7.40it/s]
# Validation DataLoader 0: 100%|██████████| 369/369 [00:49<00:00,  7.38it/s]
# Epoch 1: 100%|██████████| 835/835 [02:20<00:00,  5.93it/s, v_num=7, seq_len=94.60, valid/recall_top_k=0.997]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/369 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/369 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 1/369 [00:00<01:03,  5.83it/s]
# Validation DataLoader 0:   1%|          | 2/369 [00:00<01:38,  3.74it/s]
# Validation DataLoader 0:   1%|          | 3/369 [00:00<01:20,  4.53it/s]
# Validation DataLoader 0:   1%|          | 4/369 [00:00<01:10,  5.19it/s]
# Validation DataLoader 0:   1%|▏         | 5/369 [00:00<01:04,  5.67it/s]
# Validation DataLoader 0:   2%|▏         | 6/369 [00:00<01:00,  6.04it/s]
# Validation DataLoader 0:   2%|▏         | 7/369 [00:01<00:56,  6.35it/s]
# Validation DataLoader 0:   2%|▏         | 8/369 [00:01<00:55,  6.51it/s]
# Validation DataLoader 0:   2%|▏         | 9/369 [00:01<00:58,  6.17it/s]
# Validation DataLoader 0:   3%|▎         | 10/369 [00:01<01:08,  5.26it/s]
# Validation DataLoader 0:   3%|▎         | 11/369 [00:02<01:05,  5.45it/s]
# Validation DataLoader 0:   3%|▎         | 12/369 [00:02<01:03,  5.64it/s]
# Validation DataLoader 0:   4%|▎         | 13/369 [00:02<01:01,  5.82it/s]
# Validation DataLoader 0:   4%|▍         | 14/369 [00:02<01:00,  5.91it/s]
# Validation DataLoader 0:   4%|▍         | 15/369 [00:02<00:58,  6.07it/s]
# Validation DataLoader 0:   4%|▍         | 16/369 [00:02<00:56,  6.21it/s]
# Validation DataLoader 0:   5%|▍         | 17/369 [00:02<00:56,  6.18it/s]
# Validation DataLoader 0:   5%|▍         | 18/369 [00:03<01:00,  5.80it/s]
# Validation DataLoader 0:   5%|▌         | 19/369 [00:03<00:58,  5.93it/s]
# Validation DataLoader 0:   5%|▌         | 20/369 [00:03<00:58,  6.00it/s]
# Validation DataLoader 0:   6%|▌         | 21/369 [00:03<00:57,  6.07it/s]
# Validation DataLoader 0:   6%|▌         | 22/369 [00:03<00:56,  6.18it/s]
# Validation DataLoader 0:   6%|▌         | 23/369 [00:03<00:55,  6.26it/s]
# Validation DataLoader 0:   7%|▋         | 24/369 [00:03<00:54,  6.33it/s]
# Validation DataLoader 0:   7%|▋         | 25/369 [00:04<00:57,  5.96it/s]
# Validation DataLoader 0:   7%|▋         | 26/369 [00:04<00:57,  5.98it/s]
# Validation DataLoader 0:   7%|▋         | 27/369 [00:04<00:56,  6.06it/s]
# Validation DataLoader 0:  85%|████████▌ | 315/369 [00:42<00:07,  7.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 316/369 [00:42<00:07,  7.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 317/369 [00:42<00:07,  7.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 318/369 [00:43<00:06,  7.39it/s]
# Validation DataLoader 0:  86%|████████▋ | 319/369 [00:43<00:06,  7.39it/s]
# Validation DataLoader 0:  87%|████████▋ | 320/369 [00:43<00:06,  7.39it/s]
# Validation DataLoader 0:  87%|████████▋ | 321/369 [00:43<00:06,  7.40it/s]
# Validation DataLoader 0:  87%|████████▋ | 322/369 [00:43<00:06,  7.40it/s]
# Validation DataLoader 0:  88%|████████▊ | 323/369 [00:43<00:06,  7.40it/s]
# Validation DataLoader 0:  88%|████████▊ | 324/369 [00:43<00:06,  7.40it/s]
# Validation DataLoader 0:  88%|████████▊ | 325/369 [00:43<00:05,  7.40it/s]
# Validation DataLoader 0:  88%|████████▊ | 326/369 [00:44<00:05,  7.39it/s]
# Validation DataLoader 0:  89%|████████▊ | 327/369 [00:44<00:05,  7.39it/s]
# Validation DataLoader 0:  89%|████████▉ | 328/369 [00:44<00:05,  7.39it/s]
# Validation DataLoader 0:  89%|████████▉ | 329/369 [00:44<00:05,  7.39it/s]
# Validation DataLoader 0:  89%|████████▉ | 330/369 [00:44<00:05,  7.39it/s]
# Validation DataLoader 0:  90%|████████▉ | 331/369 [00:44<00:05,  7.39it/s]
# Validation DataLoader 0:  90%|████████▉ | 332/369 [00:44<00:05,  7.40it/s]
# Validation DataLoader 0:  90%|█████████ | 333/369 [00:45<00:04,  7.40it/s]
# Validation DataLoader 0:  91%|█████████ | 334/369 [00:45<00:04,  7.40it/s]
# Validation DataLoader 0:  91%|█████████ | 335/369 [00:45<00:04,  7.40it/s]
# Validation DataLoader 0:  91%|█████████ | 336/369 [00:45<00:04,  7.40it/s]
# Validation DataLoader 0:  91%|█████████▏| 337/369 [00:45<00:04,  7.39it/s]
# Validation DataLoader 0:  92%|█████████▏| 338/369 [00:45<00:04,  7.38it/s]
# Validation DataLoader 0:  92%|█████████▏| 339/369 [00:45<00:04,  7.38it/s]
# Validation DataLoader 0:  92%|█████████▏| 340/369 [00:46<00:03,  7.39it/s]
# Validation DataLoader 0:  92%|█████████▏| 341/369 [00:46<00:03,  7.39it/s]
# Validation DataLoader 0:  93%|█████████▎| 342/369 [00:46<00:03,  7.39it/s]
# Validation DataLoader 0:  93%|█████████▎| 343/369 [00:46<00:03,  7.39it/s]
# Validation DataLoader 0:  93%|█████████▎| 344/369 [00:46<00:03,  7.40it/s]
# Validation DataLoader 0:  93%|█████████▎| 345/369 [00:46<00:03,  7.40it/s]
# Validation DataLoader 0:  94%|█████████▍| 346/369 [00:46<00:03,  7.39it/s]
# Validation DataLoader 0:  94%|█████████▍| 347/369 [00:46<00:02,  7.40it/s]
# Validation DataLoader 0:  94%|█████████▍| 348/369 [00:47<00:02,  7.40it/s]
# Validation DataLoader 0:  95%|█████████▍| 349/369 [00:47<00:02,  7.40it/s]
# Validation DataLoader 0:  95%|█████████▍| 350/369 [00:47<00:02,  7.40it/s]
# Validation DataLoader 0:  95%|█████████▌| 351/369 [00:47<00:02,  7.40it/s]
# Validation DataLoader 0:  95%|█████████▌| 352/369 [00:47<00:02,  7.40it/s]
# Validation DataLoader 0:  96%|█████████▌| 353/369 [00:47<00:02,  7.40it/s]
# Validation DataLoader 0:  96%|█████████▌| 354/369 [00:47<00:02,  7.39it/s]
# Validation DataLoader 0:  96%|█████████▌| 355/369 [00:48<00:01,  7.39it/s]
# Validation DataLoader 0:  96%|█████████▋| 356/369 [00:48<00:01,  7.40it/s]
# Validation DataLoader 0:  97%|█████████▋| 357/369 [00:48<00:01,  7.40it/s]
# Validation DataLoader 0:  97%|█████████▋| 358/369 [00:48<00:01,  7.40it/s]
# Validation DataLoader 0:  97%|█████████▋| 359/369 [00:48<00:01,  7.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 360/369 [00:48<00:01,  7.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 361/369 [00:48<00:01,  7.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 362/369 [00:48<00:00,  7.40it/s]
# Validation DataLoader 0:  98%|█████████▊| 363/369 [00:49<00:00,  7.41it/s]
# Validation DataLoader 0:  99%|█████████▊| 364/369 [00:49<00:00,  7.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 365/369 [00:49<00:00,  7.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 366/369 [00:49<00:00,  7.41it/s]
# Validation DataLoader 0:  99%|█████████▉| 367/369 [00:49<00:00,  7.41it/s]
# Validation DataLoader 0: 100%|█████████▉| 368/369 [00:49<00:00,  7.40it/s]
# Validation DataLoader 0: 100%|██████████| 369/369 [00:49<00:00,  7.40it/s]
# Epoch 7: 100%|██████████| 835/835 [03:03<00:00,  4.56it/s, v_num=7, seq_len=93.90, valid/recall_top_k=0.997]

# %%
torch.save(model.state_dict(), "./transactions_emb64_model.pt")

# %% [markdown]
# # Part 3

# %%
processed_train = pd.read_pickle("processed_train.pkl")

# %%
# processed_target = pd.read_pickle('processed_target.pkl')
target_train = pd.read_parquet("train_target.parquet")
target_test = pd.read_parquet("test_target_b.parquet")

# %%
with open("transactions_preprocessor.pkl", "rb") as f:
    preprocessor = pickle.load(f)

# %%
import gc
gc.collect()
# Out:
# 162

# %%
trx_encoder_params = dict(
    embeddings_noise=0.003,
    numeric_values={"amount": "log"},
    embeddings={
        "event_type": {
            "in": preprocessor.get_category_dictionary_sizes()["event_type"],
            "out": 8,
        },
        "event_subtype": {
            "in": preprocessor.get_category_dictionary_sizes()["event_subtype"],
            "out": 8,
        },
        "src_type11": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type11"],
            "out": 16,
        },
        "src_type12": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type12"],
            "out": 16,
        },
        "dst_type11": {
            "in": preprocessor.get_category_dictionary_sizes()["dst_type11"],
            "out": 16,
        },
        "dst_type12": {
            "in": preprocessor.get_category_dictionary_sizes()["dst_type12"],
            "out": 16,
        },
        "src_type22": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type22"],
            "out": 16
        },
        "src_type31": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type31"],
            "out": 16,
        },
        "src_type32": {
            "in": preprocessor.get_category_dictionary_sizes()["src_type32"],
            "out": 16,
        },
    },
)

# %%
seq_encoder = RnnSeqEncoder(
    trx_encoder=TrxEncoder(**trx_encoder_params),
    hidden_size=64,
    type="gru",
)

# %%
model = CoLESModule(
    seq_encoder=seq_encoder,
    optimizer_partial=partial(torch.optim.Adam, lr=0.001),
    lr_scheduler_partial=partial(
        torch.optim.lr_scheduler.StepLR, step_size=3, gamma=0.9025
    ),
)
model.load_state_dict(torch.load('./transactions_emb64_model.pt'))
model.eval()
# Out:
# CoLESModule(
#   (_loss): ContrastiveLoss()
#   (_seq_encoder): RnnSeqEncoder(
#     (trx_encoder): TrxEncoder(
#       (embeddings): ModuleDict(
#         (event_type): NoisyEmbedding(
#           57, 8, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (event_subtype): NoisyEmbedding(
#           59, 8, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (src_type11): NoisyEmbedding(
#           81, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (src_type12): NoisyEmbedding(
#           347, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (dst_type11): NoisyEmbedding(
#           83, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (dst_type12): NoisyEmbedding(
#           409, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (src_type22): NoisyEmbedding(
#           90, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (src_type31): NoisyEmbedding(
#           2278, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#         (src_type32): NoisyEmbedding(
#           91, 16, padding_idx=0
#           (dropout): Dropout(p=0, inplace=False)
#         )
#       )
#       (custom_embeddings): ModuleDict(
#         (amount): LogScaler()
#       )
#       (custom_embedding_batch_norm): RBatchNorm(
#         (bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (seq_encoder): RnnEncoder(
#       (rnn): GRU(129, 64, batch_first=True)
#       (reducer): LastStepEncoder()
#     )
#   )
#   (_validation_metric): BatchRecallTopK()
#   (_head): Head(
#     (model): Sequential(
#       (0): L2NormEncoder()
#     )
#   )
# )

# %%
device  = torch.device("cuda")
model = model.to(device)

# %%
device
# Out:
# device(type='cuda')

# %%
from pandas.tseries.offsets import MonthBegin


class GetSplit(IterableProcessingDataset):
    def __init__(
        self,
        months,
        col_id='client_id',
        col_time='event_time'
    ):
        super().__init__()
        self.months = months
        self._col_id = col_id
        self._col_time = col_time

    def __iter__(self):
        for rec in self._src:
            for i, month in enumerate(self.months):
                features = rec[0] if type(rec) is tuple else rec
                features = features.copy()

                month_event_time = int((pd.to_datetime(month, yearfirst=True, dayfirst=False) - MonthBegin(1)).to_datetime64()) / 1e9
                mask = features[self._col_time] < month_event_time

                for key, tensor in features.items():
                    if key.startswith('target'):
                        features[key] = tensor[i].tolist()
                    elif key != self._col_id:
                        features[key] = tensor[mask]

                features[self._col_id] += '__' + str(month)

                yield features
                

from datetime import datetime


def collate_feature_dict_with_target(batch, col_id='client_id', targets=False):
    batch_ids = []
    target_cols = []
    for sample in batch:
        batch_ids.append(sample[col_id])
        del sample[col_id]

        if targets:
            target_cols.append([sample[f'target_{i}'] for i in range(1, 5)])
            del sample['target_1']
            del sample['target_2']
            del sample['target_3']
            del sample['target_4']

    padded_batch = collate_feature_dict(batch)
    if targets:
        return padded_batch, batch_ids, target_cols
    return padded_batch, batch_ids

def to_pandas(x):
    with torch.no_grad():
        expand_cols = []
        scalar_features = {}
        for k, v in x.items():
            if type(v) is torch.Tensor:
                v = v.cpu().detach().numpy()
            if type(v) is list or len(v.shape) == 1:
                scalar_features[k] = v
            elif len(v.shape) == 2:
                expand_cols.append(k)
            else:
                scalar_features[k] = None
        dataframes = [pd.DataFrame(scalar_features)]
        for col in expand_cols:
            v = x[col].cpu().detach().numpy()
            dataframes.append(pd.DataFrame(v, columns=[f'{col}_{i:04d}' for i in range(v.shape[1])]))
        return pd.concat(dataframes, axis=1)

# %%
from tqdm import tqdm

def make_prediction(model, inference_dl):
    dfs = []
    for x in tqdm(inference_dl):
        x_len = len(x)
        if x_len == 3:
            x, batch_ids, target_cols = x
        else:
            x, batch_ids = x
        out = model(x.to(device))
        if x_len == 3:
            target_cols = torch.tensor(target_cols)
            x_out = {
                'client_id': batch_ids,
                'target_1': target_cols[:, 0],
                'target_2': target_cols[:, 1],
                'target_3': target_cols[:, 2],
                'target_4': target_cols[:, 3],
                'emb': out
            }
        else:
            x_out = {
                'client_id': batch_ids,
                'emb': out
            }
        torch.cuda.empty_cache()
        dfs.append(to_pandas(x_out))
    return pd.concat(dfs, axis='rows')


def get_train_dataset(processed_data, model, months):
    train = MemoryMapDataset(
        data=processed_data.to_dict("records"),
        i_filters=[
            ISeqLenLimit(max_seq_len=4096),
            FeatureFilter(keep_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
            GetSplit(months=months),
            ToTorch(),
        ]
    )

    inference_train_dl = DataLoader(
            dataset=train,
            collate_fn=collate_feature_dict_with_target,
            shuffle=False,
            num_workers=0,
            batch_size=256,
        )
    
    train_emb_df = make_prediction(model, inference_train_dl)
    train_emb_df[['client_id', 'month']] = train_emb_df['client_id'].str.split('__', n=1, expand=True)
    return train_emb_df


def get_val_dataset(processed_data, model, months):
    val = MemoryMapDataset(
        data=processed_data.to_dict("records"),
        i_filters=[
            ISeqLenLimit(max_seq_len=4096),
            FeatureFilter(keep_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
            GetSplit(months=months),
            ToTorch(),
        ]
    )
    inference_val_dl = DataLoader(
            dataset=val,
            collate_fn=collate_feature_dict_with_target,
            shuffle=False,
            num_workers=0,
            batch_size=256,
        )
    
    val_emb_df = make_prediction(model, inference_val_dl)
    val_emb_df[['client_id', 'month']] = val_emb_df['client_id'].str.split('__', n=1, expand=True)
    return val_emb_df


def get_test_dataset(processed_data, model):
    test = MemoryMapDataset(
        data=processed_data.to_dict("records"),
        i_filters=[
            ISeqLenLimit(max_seq_len=4096),
            FeatureFilter(keep_feature_names=['client_id', 'target_1', 'target_2', 'target_3', 'target_4']),
            ToTorch(),
        ]
    )

    inference_test_dl = DataLoader(
            dataset=test,
            collate_fn=collate_feature_dict_with_target,
            shuffle=False,
            num_workers=0,
            batch_size=256,
        )
    
    test_emb_df = make_prediction(model, inference_test_dl)
    return test_emb_df

# %%
part1 = processed_train[:150_000]

# %%
train_emb_df_part1 = get_train_dataset(part1, model, sorted(target_train.mon.sort_values().unique()))

# %%
1

# %%
train_emb_df_part1

# %%
train_emb_df_part1.to_csv('train1_trans_emb_v2.csv', index=False)

# %%
1

# %%
1

# %%
1

# %%
1

# %%
1

# %%
1

# %%
val_emb_df = get_val_dataset(processed_test, model, sorted(target_test.mon.sort_values().unique()))
# Out:
# 100%|██████████| 9700/9700 [08:07<00:00, 19.90it/s]

# %%
val_emb_df.to_csv('val_trans_emb_v2.csv', index=False)

# %%
del val_emb_df

# %%
test_emb_df = get_test_dataset(processed_test, model)
# Out:
# 100%|██████████| 882/882 [01:09<00:00, 12.71it/s]

# %%
test_emb_df.to_csv('test_trans_emb_v2.csv', index=False)

# %%
del test_emb_df

# %%
del processed_test
